# %%
# Import Libraries

import numpy as np                   
import pandas as pd        
from PIL import Image
import pytesseract
import cv2

# %%
# Import Image
img_path = "./IMG_3268.jpg"
img = Image.open(img_path).convert("L")
imgx = img.copy()

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
rez = pytesseract.image_to_string(imgx)

# %%
img.show(imgx)
